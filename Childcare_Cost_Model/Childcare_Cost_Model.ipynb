# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

import plotly.express as px
from sklearn.datasets import make_blobs
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# DSC 640
# Nicolas Saenz
# Milestone 5

# %%
df = pd.read_excel('nationaldatabaseofchildcareprices.xlsx')

# %% [markdown]
# Median household income MHI_2018
# Poerty rate all families PR_F
# MEdian price of center based care up to 5 months MCBto5
# MC6to11
# MC12to17

# %%
# Basic histogram
plt.figure()
plt.hist(df["MHI_2018"], bins=30, color='skyblue', edgecolor='black')
plt.title('Basic Histogram')
plt.xlabel('Median Household Income')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Basic histogram
plt.figure()
plt.hist(df["PR_F"], bins=30, color='skyblue', edgecolor='black')
plt.title('Basic Histogram')
plt.xlabel('Poverty rate for Families')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Basic histogram
plt.figure()
plt.hist(df["MCBto5"], bins=30, color='skyblue', edgecolor='black')
plt.title('Basic Histogram')
plt.xlabel('Weekly fulltime median price for 0 to 5 months')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Basic histogram
plt.figure()
plt.hist(df["MC6to11"], bins=30, color='skyblue', edgecolor='black')
plt.title('Basic Histogram')
plt.xlabel('Weekly fulltime median price for 6 to 11 months')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Basic histogram
plt.figure()
plt.hist(df["MC12to17"], bins=30, color='skyblue', edgecolor='black')
plt.title('Basic Histogram')
plt.xlabel('Weekly fulltime median price for 12 to 17 months')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Basic histogram
plt.figure()
plt.hist(df["MC54toSA"], bins=30, color='skyblue', edgecolor='black')
plt.title('Basic Histogram')
plt.xlabel('Weekly fulltime median price for 54 months to School age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Basic histogram
plt.figure()
plt.hist(df["MFCCInfant"], bins=30, color='skyblue', edgecolor='black')
plt.title('Basic Histogram')
plt.xlabel('Median Household Income')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Basic histogram
plt.figure()
plt.hist(df["_75CInfant"], bins=30, color='skyblue', edgecolor='black')
plt.title('75th Percentile Price of Center-Based Care– Infant Weekly price')

plt.xlabel('Median Household Income')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
grouped_by_category = df.groupby('State_Name')


Average_Income_by_state = grouped_by_category['MHI_2018'].median().to_frame()
print("--- Average Quantity per Category (Median) ---")
print(Average_Income_by_state)
print(type(Average_Income_by_state))
# Out:
# --- Average Quantity per Category (Median) ---
#                        MHI_2018
# State_Name
# Alabama               40483.520
# Alaska                67913.765
# Arizona               47779.500
# Arkansas              38752.120
# California            58854.580
# Colorado              51933.150
# Connecticut           76287.530
# Delaware              60043.800
# District of Columbia  71096.400
# Florida               48173.000
# Georgia               41886.440
# Hawaii                70464.560
# Idaho                 47121.960
# Illinois              51733.900
# Indiana               51390.390
# Iowa                  52489.080
# Kansas                49230.300
# Kentucky              41752.060
# Louisiana             43804.325
# Maine                 49428.640
# Maryland              72759.900
# Massachusetts         69484.440
# Michigan              46836.160
# Minnesota             54625.020
# Mississippi           36772.985
# Missouri              43493.760
# Montana               46340.280
# Nebraska              50288.700
# Nevada                58899.680
# New Hampshire         63105.000
# New Jersey            77726.610
# New Mexico            41184.180
# New York              54917.510
# North Carolina        44789.010
# North Dakota          54935.010
# Ohio                  50859.465
# Oklahoma              46171.710
# Oregon                47924.125
# Pennsylvania          50400.090
# Rhode Island          76364.730
# South Carolina        43217.310
# South Dakota          50639.340
# Tennessee             41765.060
# Texas                 47925.075
# Utah                  55426.360
# Vermont               57038.645
# Virginia              52120.950
# Washington            52513.440
# West Virginia         40882.240
# Wisconsin             53611.250
# Wyoming               58946.940
# <class 'pandas.core.frame.DataFrame'>

# %%
# Group by 'State_Name', calculate the median, and convert the result to a DataFrame
average_income_by_state_df = df.groupby('State_Name')['MHI_2018'].median().reset_index()
print(average_income_by_state_df.columns)
print(type(average_income_by_state_df))
# Out:
# Index(['State_Name', 'MHI_2018'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>

# %%
Average_Yearly_cost_Bto5months = ((grouped_by_category['MCBto5'].median())*52).to_frame()
print(type(Average_Yearly_cost_Bto5months))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Group by 'State_Name', calculate the median, and convert the result to a DataFrame
Average_Yearly_cost_Bto5months_df = df.groupby('State_Name')['MCBto5'].median().reset_index()

print(Average_Yearly_cost_Bto5months_df.columns)
# Out:
# Index(['State_Name', 'MCBto5'], dtype='object')

# %%
#average_income_by_state_df["MHI_2018"] = average_income_by_state_df["MHI_2018"]*0.07

# %%
#Create a copy of income data and multiply the income column to find what the ncau deems as an affordable amount to spend for childcare

affordable_df = average_income_by_state_df.copy()
print(affordable_df)
affordable_df['MHI_2018'] = affordable_df['MHI_2018']*0.07
# Out:
#               State_Name   MHI_2018
# 0                Alabama  40483.520
# 1                 Alaska  67913.765
# 2                Arizona  47779.500
# 3               Arkansas  38752.120
# 4             California  58854.580
# 5               Colorado  51933.150
# 6            Connecticut  76287.530
# 7               Delaware  60043.800
# 8   District of Columbia  71096.400
# 9                Florida  48173.000
# 10               Georgia  41886.440
# 11                Hawaii  70464.560
# 12                 Idaho  47121.960
# 13              Illinois  51733.900
# 14               Indiana  51390.390
# 15                  Iowa  52489.080
# 16                Kansas  49230.300
# 17              Kentucky  41752.060
# 18             Louisiana  43804.325
# 19                 Maine  49428.640
# 20              Maryland  72759.900
# 21         Massachusetts  69484.440
# 22              Michigan  46836.160
# 23             Minnesota  54625.020
# 24           Mississippi  36772.985
# 25              Missouri  43493.760
# 26               Montana  46340.280
# 27              Nebraska  50288.700
# 28                Nevada  58899.680
# 29         New Hampshire  63105.000
# 30            New Jersey  77726.610
# 31            New Mexico  41184.180
# 32              New York  54917.510
# 33        North Carolina  44789.010
# 34          North Dakota  54935.010
# 35                  Ohio  50859.465
# 36              Oklahoma  46171.710
# 37                Oregon  47924.125
# 38          Pennsylvania  50400.090
# 39          Rhode Island  76364.730
# 40        South Carolina  43217.310
# 41          South Dakota  50639.340
# 42             Tennessee  41765.060
# 43                 Texas  47925.075
# 44                  Utah  55426.360
# 45               Vermont  57038.645
# 46              Virginia  52120.950
# 47            Washington  52513.440
# 48         West Virginia  40882.240
# 49             Wisconsin  53611.250
# 50               Wyoming  58946.940

# %%
print(affordable_df)
# Out:
#               State_Name    MHI_2018
# 0                Alabama  2833.84640
# 1                 Alaska  4753.96355
# 2                Arizona  3344.56500
# 3               Arkansas  2712.64840
# 4             California  4119.82060
# 5               Colorado  3635.32050
# 6            Connecticut  5340.12710
# 7               Delaware  4203.06600
# 8   District of Columbia  4976.74800
# 9                Florida  3372.11000
# 10               Georgia  2932.05080
# 11                Hawaii  4932.51920
# 12                 Idaho  3298.53720
# 13              Illinois  3621.37300
# 14               Indiana  3597.32730
# 15                  Iowa  3674.23560
# 16                Kansas  3446.12100
# 17              Kentucky  2922.64420
# 18             Louisiana  3066.30275
# 19                 Maine  3460.00480
# 20              Maryland  5093.19300
# 21         Massachusetts  4863.91080
# 22              Michigan  3278.53120
# 23             Minnesota  3823.75140
# 24           Mississippi  2574.10895
# 25              Missouri  3044.56320
# 26               Montana  3243.81960
# 27              Nebraska  3520.20900
# 28                Nevada  4122.97760
# 29         New Hampshire  4417.35000
# 30            New Jersey  5440.86270
# 31            New Mexico  2882.89260
# 32              New York  3844.22570
# 33        North Carolina  3135.23070
# 34          North Dakota  3845.45070
# 35                  Ohio  3560.16255
# 36              Oklahoma  3232.01970
# 37                Oregon  3354.68875
# 38          Pennsylvania  3528.00630
# 39          Rhode Island  5345.53110
# 40        South Carolina  3025.21170
# 41          South Dakota  3544.75380
# 42             Tennessee  2923.55420
# 43                 Texas  3354.75525
# 44                  Utah  3879.84520
# 45               Vermont  3992.70515
# 46              Virginia  3648.46650
# 47            Washington  3675.94080
# 48         West Virginia  2861.75680
# 49             Wisconsin  3752.78750
# 50               Wyoming  4126.28580

# %% [markdown]
# merge these data sets on state
#
# Explore quality, licensing reuirements
#
# Make a side by side bar chart to compare median income vs yearly cost by state

# %%
# --- 2. Prepare Data for Plotting ---
# Get the labels for the x-axis from the common 'quarter' column.
labels = average_income_by_state_df['State_Name']

# Get the values to plot from each DataFrame.
values1 = average_income_by_state_df['MHI_2018']
values2 = Average_Yearly_cost_Bto5months_df['MCBto5']*52
values3 = affordable_df['MHI_2018']

# Define the positions for the bars on the x-axis.
x = np.arange(len(labels)) * 2
width = 0.35  # the width of the bars


fig, ax = plt.subplots(figsize=(12, 6))

rects1 = ax.bar(x - width, values1, width, label='income', color='skyblue')

rects2 = ax.bar(x, values2, width, label='Childcare cost', color='sandybrown')

rects3 = ax.bar(x + width, values3, width, label='Affordable Childcare cost', color='chartreuse')


# Add Labels, Title, and Formatting
# Add some text for labels, title and axes ticks.
ax.set_ylabel('Dollars (US)')
ax.set_title('Income and Childcare Cost by State')

# Set the x-axis ticks 
ax.set_xticks(x)
ax.set_xticklabels(labels)
# Rotate the x-axis labels for better readability
ax.set_xticklabels(labels, rotation=45, ha='right')

ax.legend()

# Add labels 
ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)
#ax.bar_label(rects3, padding=3)

fig.tight_layout()
plt.show()

# %%
# Merge the two DataFrames using the 'state' column as the key
merged_df = pd.merge(Average_Yearly_cost_Bto5months_df, affordable_df, on='State_Name')

print(merged_df)
# Out:
#               State_Name   MCBto5    MHI_2018
# 0                Alabama  105.990  2833.84640
# 1                 Alaska  225.120  4753.96355
# 2                Arizona  161.500  3344.56500
# 3               Arkansas   97.500  2712.64840
# 4             California  258.145  4119.82060
# 5               Colorado  173.400  3635.32050
# 6            Connecticut  243.000  5340.12710
# 7               Delaware  171.020  4203.06600
# 8   District of Columbia  303.580  4976.74800
# 9                Florida  142.500  3372.11000
# 10               Georgia   95.000  2932.05080
# 11                Hawaii  281.250  4932.51920
# 12                 Idaho  101.880  3298.53720
# 13              Illinois  166.330  3621.37300
# 14               Indiana      NaN  3597.32730
# 15                  Iowa  150.130  3674.23560
# 16                Kansas   99.400  3446.12100
# 17              Kentucky  110.000  2922.64420
# 18             Louisiana  109.000  3066.30275
# 19                 Maine  173.000  3460.00480
# 20              Maryland  212.560  5093.19300
# 21         Massachusetts  276.565  4863.91080
# 22              Michigan  141.840  3278.53120
# 23             Minnesota  168.000  3823.75140
# 24           Mississippi   76.810  2574.10895
# 25              Missouri  131.350  3044.56320
# 26               Montana  140.325  3243.81960
# 27              Nebraska  133.200  3520.20900
# 28                Nevada  141.930  4122.97760
# 29         New Hampshire  213.820  4417.35000
# 30            New Jersey  197.980  5440.86270
# 31            New Mexico      NaN  2882.89260
# 32              New York  219.775  3844.22570
# 33        North Carolina  157.640  3135.23070
# 34          North Dakota  125.410  3845.45070
# 35                  Ohio  159.750  3560.16255
# 36              Oklahoma  133.480  3232.01970
# 37                Oregon  153.365  3354.68875
# 38          Pennsylvania  160.000  3528.00630
# 39          Rhode Island  270.640  5345.53110
# 40        South Carolina  122.500  3025.21170
# 41          South Dakota   94.790  3544.75380
# 42             Tennessee  114.000  2923.55420
# 43                 Texas  116.200  3354.75525
# 44                  Utah  143.650  3879.84520
# 45               Vermont  182.865  3992.70515
# 46              Virginia  150.000  3648.46650
# 47            Washington  244.620  3675.94080
# 48         West Virginia  117.690  2861.75680
# 49             Wisconsin  175.000  3752.78750
# 50               Wyoming  140.300  4126.28580

# %%
# Introduce a new column calculating what child care costs for a year for a single child.
merged_df['Dollars Above Affordability'] = ((merged_df['MCBto5'])*52) - merged_df['MHI_2018']

print(merged_df)
# Out:
#               State_Name   MCBto5    MHI_2018  Dollars Above Affordability
# 0                Alabama  105.990  2833.84640                   2677.63360
# 1                 Alaska  225.120  4753.96355                   6952.27645
# 2                Arizona  161.500  3344.56500                   5053.43500
# 3               Arkansas   97.500  2712.64840                   2357.35160
# 4             California  258.145  4119.82060                   9303.71940
# 5               Colorado  173.400  3635.32050                   5381.47950
# 6            Connecticut  243.000  5340.12710                   7295.87290
# 7               Delaware  171.020  4203.06600                   4689.97400
# 8   District of Columbia  303.580  4976.74800                  10809.41200
# 9                Florida  142.500  3372.11000                   4037.89000
# 10               Georgia   95.000  2932.05080                   2007.94920
# 11                Hawaii  281.250  4932.51920                   9692.48080
# 12                 Idaho  101.880  3298.53720                   1999.22280
# 13              Illinois  166.330  3621.37300                   5027.78700
# 14               Indiana      NaN  3597.32730                          NaN
# 15                  Iowa  150.130  3674.23560                   4132.52440
# 16                Kansas   99.400  3446.12100                   1722.67900
# 17              Kentucky  110.000  2922.64420                   2797.35580
# 18             Louisiana  109.000  3066.30275                   2601.69725
# 19                 Maine  173.000  3460.00480                   5535.99520
# 20              Maryland  212.560  5093.19300                   5959.92700
# 21         Massachusetts  276.565  4863.91080                   9517.46920
# 22              Michigan  141.840  3278.53120                   4097.14880
# 23             Minnesota  168.000  3823.75140                   4912.24860
# 24           Mississippi   76.810  2574.10895                   1420.01105
# 25              Missouri  131.350  3044.56320                   3785.63680
# 26               Montana  140.325  3243.81960                   4053.08040
# 27              Nebraska  133.200  3520.20900                   3406.19100
# 28                Nevada  141.930  4122.97760                   3257.38240
# 29         New Hampshire  213.820  4417.35000                   6701.29000
# 30            New Jersey  197.980  5440.86270                   4854.09730
# 31            New Mexico      NaN  2882.89260                          NaN
# 32              New York  219.775  3844.22570                   7584.07430
# 33        North Carolina  157.640  3135.23070                   5062.04930
# 34          North Dakota  125.410  3845.45070                   2675.86930
# 35                  Ohio  159.750  3560.16255                   4746.83745
# 36              Oklahoma  133.480  3232.01970                   3708.94030
# 37                Oregon  153.365  3354.68875                   4620.29125
# 38          Pennsylvania  160.000  3528.00630                   4791.99370
# 39          Rhode Island  270.640  5345.53110                   8727.74890
# 40        South Carolina  122.500  3025.21170                   3344.78830
# 41          South Dakota   94.790  3544.75380                   1384.32620
# 42             Tennessee  114.000  2923.55420                   3004.44580
# 43                 Texas  116.200  3354.75525                   2687.64475
# 44                  Utah  143.650  3879.84520                   3589.95480
# 45               Vermont  182.865  3992.70515                   5516.27485
# 46              Virginia  150.000  3648.46650                   4151.53350
# 47            Washington  244.620  3675.94080                   9044.29920
# 48         West Virginia  117.690  2861.75680                   3258.12320
# 49             Wisconsin  175.000  3752.78750                   5347.21250
# 50               Wyoming  140.300  4126.28580                   3169.31420

# %%
#care data is ranked on a scale of 1 to 4 1 besing the least and 4 being the most

df2 = pd.read_csv("Care Data(Sheet1).csv")

print(df2)
# Out:
#         State_Name  Quality  Availability
# 0      Connecticut        4             4
# 1    New Hampshire        3             4
# 2    Massachusetts        4             4
# 3     Rhode Island        3             4
# 4        Minnesota        4             3
# 5          Vermont        4             4
# 6         Maryland        3             4
# 7            Maine        3             4
# 8       New Jersey        1             4
# 9           Hawaii        4             1
# 10        Virginia        2             4
# 11         Wyoming        4             1
# 12        Delaware        1             4
# 13    Pennsylvania        3             3
# 14            Iowa        4             2
# 15    North Dakota        1             3
# 16        Colorado        2             3
# 17         Georgia        3             3
# 18         Florida        3             3
# 19        Missouri        3             2
# 20        Nebraska        1             2
# 21        Michigan        1             3
# 22       Wisconsin        1             3
# 23  South Carolina        4             3
# 24  North Carolina        4             4
# 25           Idaho        4             1
# 26          Oregon        2             3
# 27        Illinois        2             3
# 28      Washington        2             3
# 29         Montana        1             2
# 30           Texas        1             1
# 31         Indiana        4             2
# 32        Arkansas        3             1
# 33      California        2             2
# 34          Kansas        2             2
# 35    South Dakota        2             1
# 36         Alabama        4             2
# 37            Utah        2             1
# 38        New York        1             4
# 39            Ohio        1             3
# 40         Arizona        2             1
# 41       Louisiana        3             1
# 42        Kentucky        2             2
# 43       Tennessee        3             2
# 44          Alaska        1             1
# 45        Oklahoma        1             1
# 46          Nevada        2             1
# 47      New Mexico        3             1
# 48     Mississippi        3             2
# 49   West Virginia        1             2

# %%
df2['Combined Qual and Aval Score'] = ((df2['Quality']) + df2['Availability']) / 2

# %%
print(df2)
# Out:
#         State_Name  Quality  Availability  Combined Qual and Aval Score
# 0      Connecticut        4             4                           4.0
# 1    New Hampshire        3             4                           3.5
# 2    Massachusetts        4             4                           4.0
# 3     Rhode Island        3             4                           3.5
# 4        Minnesota        4             3                           3.5
# 5          Vermont        4             4                           4.0
# 6         Maryland        3             4                           3.5
# 7            Maine        3             4                           3.5
# 8       New Jersey        1             4                           2.5
# 9           Hawaii        4             1                           2.5
# 10        Virginia        2             4                           3.0
# 11         Wyoming        4             1                           2.5
# 12        Delaware        1             4                           2.5
# 13    Pennsylvania        3             3                           3.0
# 14            Iowa        4             2                           3.0
# 15    North Dakota        1             3                           2.0
# 16        Colorado        2             3                           2.5
# 17         Georgia        3             3                           3.0
# 18         Florida        3             3                           3.0
# 19        Missouri        3             2                           2.5
# 20        Nebraska        1             2                           1.5
# 21        Michigan        1             3                           2.0
# 22       Wisconsin        1             3                           2.0
# 23  South Carolina        4             3                           3.5
# 24  North Carolina        4             4                           4.0
# 25           Idaho        4             1                           2.5
# 26          Oregon        2             3                           2.5
# 27        Illinois        2             3                           2.5
# 28      Washington        2             3                           2.5
# 29         Montana        1             2                           1.5
# 30           Texas        1             1                           1.0
# 31         Indiana        4             2                           3.0
# 32        Arkansas        3             1                           2.0
# 33      California        2             2                           2.0
# 34          Kansas        2             2                           2.0
# 35    South Dakota        2             1                           1.5
# 36         Alabama        4             2                           3.0
# 37            Utah        2             1                           1.5
# 38        New York        1             4                           2.5
# 39            Ohio        1             3                           2.0
# 40         Arizona        2             1                           1.5
# 41       Louisiana        3             1                           2.0
# 42        Kentucky        2             2                           2.0
# 43       Tennessee        3             2                           2.5
# 44          Alaska        1             1                           1.0
# 45        Oklahoma        1             1                           1.0
# 46          Nevada        2             1                           1.5
# 47      New Mexico        3             1                           2.0
# 48     Mississippi        3             2                           2.5
# 49   West Virginia        1             2                           1.5

# %%
categories = df2['State_Name']
values = df2['Combined Qual and Aval Score']
colors = ['darkcyan']

plt.figure(figsize=(10, 6))
plt.bar(categories, values, color=colors)

x = np.arange(len(labels)) * 2

plt.title('Quality and Availability')
plt.xlabel('State')
plt.ylabel('Combined Quality and Availability Score (1 low, 4 high)')

plt.xticks(rotation=45, ha='right')

plt.tight_layout()

plt.show()

# %%
mean_value1 = merged_df['MCBto5'].mean()
mean_value2 = merged_df['Dollars Above Affordability'].mean()

# %%
# Replace missing values for new mexico and Indiana based on mean
merged_df['MCBto5'].fillna(mean_value1, inplace=True)
merged_df['Dollars Above Affordability'].fillna(mean_value2, inplace=True)

print(merged_df)
# Out:
#               State_Name      MCBto5    MHI_2018  Dollars Above Affordability
# 0                Alabama  105.990000  2833.84640                  2677.633600
# 1                 Alaska  225.120000  4753.96355                  6952.276450
# 2                Arizona  161.500000  3344.56500                  5053.435000
# 3               Arkansas   97.500000  2712.64840                  2357.351600
# 4             California  258.145000  4119.82060                  9303.719400
# 5               Colorado  173.400000  3635.32050                  5381.479500
# 6            Connecticut  243.000000  5340.12710                  7295.872900
# 7               Delaware  171.020000  4203.06600                  4689.974000
# 8   District of Columbia  303.580000  4976.74800                 10809.412000
# 9                Florida  142.500000  3372.11000                  4037.890000
# 10               Georgia   95.000000  2932.05080                  2007.949200
# 11                Hawaii  281.250000  4932.51920                  9692.480800
# 12                 Idaho  101.880000  3298.53720                  1999.222800
# 13              Illinois  166.330000  3621.37300                  5027.787000
# 14               Indiana  162.934694  3597.32730                  4744.019189
# 15                  Iowa  150.130000  3674.23560                  4132.524400
# 16                Kansas   99.400000  3446.12100                  1722.679000
# 17              Kentucky  110.000000  2922.64420                  2797.355800
# 18             Louisiana  109.000000  3066.30275                  2601.697250
# 19                 Maine  173.000000  3460.00480                  5535.995200
# 20              Maryland  212.560000  5093.19300                  5959.927000
# 21         Massachusetts  276.565000  4863.91080                  9517.469200
# 22              Michigan  141.840000  3278.53120                  4097.148800
# 23             Minnesota  168.000000  3823.75140                  4912.248600
# 24           Mississippi   76.810000  2574.10895                  1420.011050
# 25              Missouri  131.350000  3044.56320                  3785.636800
# 26               Montana  140.325000  3243.81960                  4053.080400
# 27              Nebraska  133.200000  3520.20900                  3406.191000
# 28                Nevada  141.930000  4122.97760                  3257.382400
# 29         New Hampshire  213.820000  4417.35000                  6701.290000
# 30            New Jersey  197.980000  5440.86270                  4854.097300
# 31            New Mexico  162.934694  2882.89260                  4744.019189
# 32              New York  219.775000  3844.22570                  7584.074300
# 33        North Carolina  157.640000  3135.23070                  5062.049300
# 34          North Dakota  125.410000  3845.45070                  2675.869300
# 35                  Ohio  159.750000  3560.16255                  4746.837450
# 36              Oklahoma  133.480000  3232.01970                  3708.940300
# 37                Oregon  153.365000  3354.68875                  4620.291250
# 38          Pennsylvania  160.000000  3528.00630                  4791.993700
# 39          Rhode Island  270.640000  5345.53110                  8727.748900
# 40        South Carolina  122.500000  3025.21170                  3344.788300
# 41          South Dakota   94.790000  3544.75380                  1384.326200
# 42             Tennessee  114.000000  2923.55420                  3004.445800
# 43                 Texas  116.200000  3354.75525                  2687.644750
# 44                  Utah  143.650000  3879.84520                  3589.954800
# 45               Vermont  182.865000  3992.70515                  5516.274850
# 46              Virginia  150.000000  3648.46650                  4151.533500
# 47            Washington  244.620000  3675.94080                  9044.299200
# 48         West Virginia  117.690000  2861.75680                  3258.123200
# 49             Wisconsin  175.000000  3752.78750                  5347.212500
# 50               Wyoming  140.300000  4126.28580                  3169.314200
# /var/folders/g9/dfcxkg0952scvgx9_4_jm4fc0000gn/T/ipykernel_73637/3607313228.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['MCBto5'].fillna(mean_value1, inplace=True)
# /var/folders/g9/dfcxkg0952scvgx9_4_jm4fc0000gn/T/ipykernel_73637/3607313228.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['Dollars Above Affordability'].fillna(mean_value2, inplace=True)

# %%
# merge our data by state on affordability, availibility and quality

merged_df2 = pd.merge(merged_df, df2, on='State_Name')
print(merged_df2)
# Out:
#         State_Name      MCBto5    MHI_2018  Dollars Above Affordability  \
# 0          Alabama  105.990000  2833.84640                  2677.633600
# 1           Alaska  225.120000  4753.96355                  6952.276450
# 2          Arizona  161.500000  3344.56500                  5053.435000
# 3         Arkansas   97.500000  2712.64840                  2357.351600
# 4       California  258.145000  4119.82060                  9303.719400
# 5         Colorado  173.400000  3635.32050                  5381.479500
# 6      Connecticut  243.000000  5340.12710                  7295.872900
# 7         Delaware  171.020000  4203.06600                  4689.974000
# 8          Florida  142.500000  3372.11000                  4037.890000
# 9          Georgia   95.000000  2932.05080                  2007.949200
# 10          Hawaii  281.250000  4932.51920                  9692.480800
# 11           Idaho  101.880000  3298.53720                  1999.222800
# 12        Illinois  166.330000  3621.37300                  5027.787000
# 13         Indiana  162.934694  3597.32730                  4744.019189
# 14            Iowa  150.130000  3674.23560                  4132.524400
# 15          Kansas   99.400000  3446.12100                  1722.679000
# 16        Kentucky  110.000000  2922.64420                  2797.355800
# 17       Louisiana  109.000000  3066.30275                  2601.697250
# 18           Maine  173.000000  3460.00480                  5535.995200
# 19        Maryland  212.560000  5093.19300                  5959.927000
# 20   Massachusetts  276.565000  4863.91080                  9517.469200
# 21        Michigan  141.840000  3278.53120                  4097.148800
# 22       Minnesota  168.000000  3823.75140                  4912.248600
# 23     Mississippi   76.810000  2574.10895                  1420.011050
# 24        Missouri  131.350000  3044.56320                  3785.636800
# 25         Montana  140.325000  3243.81960                  4053.080400
# 26        Nebraska  133.200000  3520.20900                  3406.191000
# 27          Nevada  141.930000  4122.97760                  3257.382400
# 28   New Hampshire  213.820000  4417.35000                  6701.290000
# 29      New Jersey  197.980000  5440.86270                  4854.097300
# 30      New Mexico  162.934694  2882.89260                  4744.019189
# 31        New York  219.775000  3844.22570                  7584.074300
# 32  North Carolina  157.640000  3135.23070                  5062.049300
# 33    North Dakota  125.410000  3845.45070                  2675.869300
# 34            Ohio  159.750000  3560.16255                  4746.837450
# 35        Oklahoma  133.480000  3232.01970                  3708.940300
# 36          Oregon  153.365000  3354.68875                  4620.291250
# 37    Pennsylvania  160.000000  3528.00630                  4791.993700
# 38    Rhode Island  270.640000  5345.53110                  8727.748900
# 39  South Carolina  122.500000  3025.21170                  3344.788300
# 40    South Dakota   94.790000  3544.75380                  1384.326200
# 41       Tennessee  114.000000  2923.55420                  3004.445800
# 42           Texas  116.200000  3354.75525                  2687.644750
# 43            Utah  143.650000  3879.84520                  3589.954800
# 44         Vermont  182.865000  3992.70515                  5516.274850
# 45        Virginia  150.000000  3648.46650                  4151.533500
# 46      Washington  244.620000  3675.94080                  9044.299200
# 47   West Virginia  117.690000  2861.75680                  3258.123200
# 48       Wisconsin  175.000000  3752.78750                  5347.212500
# 49         Wyoming  140.300000  4126.28580                  3169.314200
#
#     Quality  Availability  Combined Qual and Aval Score
# 0         4             2                           3.0
# 1         1             1                           1.0
# 2         2             1                           1.5
# 3         3             1                           2.0
# 4         2             2                           2.0
# 5         2             3                           2.5
# 6         4             4                           4.0
# 7         1             4                           2.5
# 8         3             3                           3.0
# 9         3             3                           3.0
# 10        4             1                           2.5
# 11        4             1                           2.5
# 12        2             3                           2.5
# 13        4             2                           3.0
# 14        4             2                           3.0
# 15        2             2                           2.0
# 16        2             2                           2.0
# 17        3             1                           2.0
# 18        3             4                           3.5
# 19        3             4                           3.5
# 20        4             4                           4.0
# 21        1             3                           2.0
# 22        4             3                           3.5
# 23        3             2                           2.5
# 24        3             2                           2.5
# 25        1             2                           1.5
# 26        1             2                           1.5
# 27        2             1                           1.5
# 28        3             4                           3.5
# 29        1             4                           2.5
# 30        3             1                           2.0
# 31        1             4                           2.5
# 32        4             4                           4.0
# 33        1             3                           2.0
# 34        1             3                           2.0
# 35        1             1                           1.0
# 36        2             3                           2.5
# 37        3             3                           3.0
# 38        3             4                           3.5
# 39        4             3                           3.5
# 40        2             1                           1.5
# 41        3             2                           2.5
# 42        1             1                           1.0
# 43        2             1                           1.5
# 44        4             4                           4.0
# 45        2             4                           3.0
# 46        2             3                           2.5
# 47        1             2                           1.5
# 48        1             3                           2.0
# 49        4             1                           2.5

# %%
# Select and Scale the Data
# Define the columns you want to use for clustering
columns_for_clustering = ['Quality', 'Availability', 'Dollars Above Affordability']
data_for_clustering = merged_df2[columns_for_clustering]

# Initialize the scaler
scaler = StandardScaler()

# Fit the scaler to the data and transform it
scaled_data = scaler.fit_transform(data_for_clustering)

# Build the K-Means Model
# Note: You should determine the ideal number of clusters using the Elbow Method or Silhouette Score.
# We'll use k=4 as an example.
kmeans = KMeans(n_clusters=3, n_init='auto', random_state=42)

# Fit the model to the SCALED data
kmeans.fit(scaled_data)

# View the Results
# Display the first few rows with the new 'Cluster' column
print(merged_df2.head())
# Out:
#    State_Name   MCBto5    MHI_2018  Dollars Above Affordability  Quality  \
# 0     Alabama  105.990  2833.84640                   2677.63360        4
# 1      Alaska  225.120  4753.96355                   6952.27645        1
# 2     Arizona  161.500  3344.56500                   5053.43500        2
# 3    Arkansas   97.500  2712.64840                   2357.35160        3
# 4  California  258.145  4119.82060                   9303.71940        2
#
#    Availability  Combined Qual and Aval Score
# 0             2                           3.0
# 1             1                           1.0
# 2             1                           1.5
# 3             1                           2.0
# 4             2                           2.0

# %%
df_3d = pd.DataFrame(merged_df2, columns=['State_Name', 'Quality', 'Availability', 'Dollars Above Affordability'])

X = df_3d[['Quality', 'Availability', 'Dollars Above Affordability']]

# %%
#Determine the best number of clusters for our model using the elbow method

#Calculate inertia for a range of cluster numbers
inertia_values = []
k_range = range(1, 11) # Test k from 1 to 10

for k in k_range:
    # Initialize and fit the KMeans model
    kmeans = KMeans(n_clusters=k, random_state=42, n_init='auto')
    kmeans.fit(X)
    # Store the inertia for this value of k
    inertia_values.append(kmeans.inertia_)

#Plot the elbow curve
plt.figure(figsize=(10, 6))
plt.plot(k_range, inertia_values, marker='o', linestyle='--')

plt.title('Elbow Method for Optimal k in 3D K-Means')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia (Within-cluster sum of squares)')
plt.xticks(k_range)
plt.grid(True)
plt.show()

# %%
# Apply K-Means Clustering
kmeans_model = KMeans(
    n_clusters=4,
    init='k-means++',
    n_init='auto',
    random_state=42
)

# %%
print(df_3d)
# Out:
#         State_Name  Quality  Availability  Dollars Above Affordability  \
# 0          Alabama        4             2                  2677.633600
# 1           Alaska        1             1                  6952.276450
# 2          Arizona        2             1                  5053.435000
# 3         Arkansas        3             1                  2357.351600
# 4       California        2             2                  9303.719400
# 5         Colorado        2             3                  5381.479500
# 6      Connecticut        4             4                  7295.872900
# 7         Delaware        1             4                  4689.974000
# 8          Florida        3             3                  4037.890000
# 9          Georgia        3             3                  2007.949200
# 10          Hawaii        4             1                  9692.480800
# 11           Idaho        4             1                  1999.222800
# 12        Illinois        2             3                  5027.787000
# 13         Indiana        4             2                  4744.019189
# 14            Iowa        4             2                  4132.524400
# 15          Kansas        2             2                  1722.679000
# 16        Kentucky        2             2                  2797.355800
# 17       Louisiana        3             1                  2601.697250
# 18           Maine        3             4                  5535.995200
# 19        Maryland        3             4                  5959.927000
# 20   Massachusetts        4             4                  9517.469200
# 21        Michigan        1             3                  4097.148800
# 22       Minnesota        4             3                  4912.248600
# 23     Mississippi        3             2                  1420.011050
# 24        Missouri        3             2                  3785.636800
# 25         Montana        1             2                  4053.080400
# 26        Nebraska        1             2                  3406.191000
# 27          Nevada        2             1                  3257.382400
# 28   New Hampshire        3             4                  6701.290000
# 29      New Jersey        1             4                  4854.097300
# 30      New Mexico        3             1                  4744.019189
# 31        New York        1             4                  7584.074300
# 32  North Carolina        4             4                  5062.049300
# 33    North Dakota        1             3                  2675.869300
# 34            Ohio        1             3                  4746.837450
# 35        Oklahoma        1             1                  3708.940300
# 36          Oregon        2             3                  4620.291250
# 37    Pennsylvania        3             3                  4791.993700
# 38    Rhode Island        3             4                  8727.748900
# 39  South Carolina        4             3                  3344.788300
# 40    South Dakota        2             1                  1384.326200
# 41       Tennessee        3             2                  3004.445800
# 42           Texas        1             1                  2687.644750
# 43            Utah        2             1                  3589.954800
# 44         Vermont        4             4                  5516.274850
# 45        Virginia        2             4                  4151.533500
# 46      Washington        2             3                  9044.299200
# 47   West Virginia        1             2                  3258.123200
# 48       Wisconsin        1             3                  5347.212500
# 49         Wyoming        4             1                  3169.314200
#
#     cluster           highlight
# 0         3             Outside
# 1         0             Outside
# 2         0             Outside
# 3         3             Outside
# 4         2             Outside
# 5         0             Outside
# 6         2             Outside
# 7         0             Outside
# 8         1  In Selected Region
# 9         3  In Selected Region
# 10        2             Outside
# 11        3             Outside
# 12        0             Outside
# 13        0             Outside
# 14        1             Outside
# 15        3             Outside
# 16        3             Outside
# 17        3             Outside
# 18        0             Outside
# 19        0             Outside
# 20        2             Outside
# 21        1             Outside
# 22        0  In Selected Region
# 23        3             Outside
# 24        1             Outside
# 25        1             Outside
# 26        1             Outside
# 27        1             Outside
# 28        0             Outside
# 29        0             Outside
# 30        0             Outside
# 31        2             Outside
# 32        0             Outside
# 33        3             Outside
# 34        0             Outside
# 35        1             Outside
# 36        0             Outside
# 37        0  In Selected Region
# 38        2             Outside
# 39        1  In Selected Region
# 40        3             Outside
# 41        1             Outside
# 42        3             Outside
# 43        1             Outside
# 44        0             Outside
# 45        1             Outside
# 46        2             Outside
# 47        1             Outside
# 48        0             Outside
# 49        1             Outside

# %%
# Fit the model without including labels
df_3d['cluster'] = kmeans_model.fit_predict(X)


# Visualize the 3D Clusters
fig = px.scatter_3d(
    df_3d,
    x='Quality',
    y='Availability',
    z='Dollars Above Affordability',
    color='cluster',
    text='State_Name',            
    hover_name='State_Name',      
    title="3D K-Means Clustering",
    labels={'cluster': 'Cluster ID'}
)

# %%
# Improve layout
fig.update_layout(
    margin=dict(l=0, r=0, b=0, t=40) # Tighten the plot margins
)

fig.show()
# Out:
# <div>                            <div id="2ec44886-9813-4c17-9729-bb5520781ed0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2ec44886-9813-4c17-9729-bb5520781ed0")) {                    Plotly.newPlot(                        "2ec44886-9813-4c17-9729-bb5520781ed0",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eQuality=%{x}\u003cbr\u003eAvailability=%{y}\u003cbr\u003eDollars Above Affordability=%{z}\u003cbr\u003eState_Name=%{text}\u003cbr\u003eCluster ID=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Alabama","Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland","Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana","Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York","North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania","Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah","Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"],"legendgroup":"","marker":{"color":[3,0,0,3,2,0,2,0,1,3,2,3,0,0,1,3,3,3,0,0,2,1,0,3,1,1,1,1,0,0,0,2,0,3,0,1,0,0,2,1,3,1,3,1,0,1,2,1,0,1],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers+text","name":"","scene":"scene","showlegend":false,"text":["Alabama","Alaska","Arizona","Arkansas","California","Colorado","Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois","Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland","Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana","Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York","North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania","Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah","Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"],"x":[4,1,2,3,2,2,4,1,3,3,4,4,2,4,4,2,2,3,3,3,4,1,4,3,3,1,1,2,3,1,3,1,4,1,1,1,2,3,3,4,2,3,1,2,4,2,2,1,1,4],"y":[2,1,1,1,2,3,4,4,3,3,1,1,3,2,2,2,2,1,4,4,4,3,3,2,2,2,2,1,4,4,1,4,4,3,3,1,3,3,4,3,1,2,1,1,4,4,3,2,3,1],"z":[2677.6335999999997,6952.276449999999,5053.4349999999995,2357.3515999999995,9303.719399999998,5381.479500000001,7295.872899999999,4689.974,4037.89,2007.9491999999996,9692.4808,1999.2228,5027.787,4744.019188775509,4132.5244,1722.6789999999996,2797.3558,2601.6972499999997,5535.995199999999,5959.927000000001,9517.4692,4097.1488,4912.2486,1420.0110499999996,3785.6368,4053.0803999999994,3406.1909999999993,3257.3824000000004,6701.289999999999,4854.0972999999985,4744.019188775509,7584.074300000001,5062.049299999999,2675.8692999999994,4746.83745,3708.940299999999,4620.29125,4791.9937,8727.748899999999,3344.7882999999997,1384.3262,3004.4458,2687.6447499999995,3589.9548,5516.274849999999,4151.5335,9044.2992,3258.1232,5347.2125,3169.3142],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666 ...

# %%
# Fit the model without including labels
df_3d['cluster'] = kmeans_model.fit_predict(X)


# Visualize the 3D Clusters
fig = px.scatter_3d(
    df_3d,
    x='Quality',
    y='Availability',
    z='Dollars Above Affordability',
    color='cluster',    
    title="3D K-Means Clustering",
    labels={'cluster': 'Cluster ID'}
)

# Improve layout
fig.update_layout(
    margin=dict(l=0, r=0, b=0, t=40) # Tighten the plot margins
)

fig.show()

# %%
# Define the Bounding Box and Apply the Mask
x_bounds = [2.5, 9.5]
y_bounds = [2.5, 9.5]
z_bounds = [0, 5500]

# Create the boolean mask using your DataFrame columns
mask = (df_3d['Quality'] >= x_bounds[0]) & (df_3d['Quality'] <= x_bounds[1]) & \
       (df_3d['Availability'] >= y_bounds[0]) & (df_3d['Availability'] <= y_bounds[1]) & \
       (df_3d['Dollars Above Affordability'] >= z_bounds[0]) & (df_3d['Dollars Above Affordability'] <= z_bounds[1])

# Filter the DataFrame to Keep Only Points INSIDE the Region
# This is the key step. We create a new DataFrame from the mask.
df_in_region = df_3d[mask].copy() # .copy() is used to avoid a SettingWithCopyWarning

# Display the change in size
print(f"Points in original DataFrame: {len(df_3d)}")
print(f"Points after filtering for region: {len(df_in_region)}")

# Visualize Only the Points from the Selected Region
# Notice the first argument is now our new, filtered DataFrame.
fig = px.scatter_3d(
    df_in_region, # <-- We are using the filtered data here
    x='Quality',
    y='Availability',
    z='Dollars Above Affordability',
    color='cluster',
    text='State_Name',
    hover_name='State_Name',
    title="3D K-Means: Showing Only Points in Selected Region",
    labels={'cluster': 'Cluster ID'}
)

fig.update_traces(textposition='top center')
fig.show()
# Out:
# Points in original DataFrame: 50
# Points after filtering for region: 6

# %%
# Define the Bounding Box and Apply the Mask
x_bounds = [1, 2.4]
y_bounds = [1, 2.4]
z_bounds = [5000, 9500]

# Create the boolean mask using your DataFrame columns
mask = (df_3d['Quality'] >= x_bounds[0]) & (df_3d['Quality'] <= x_bounds[1]) & \
       (df_3d['Availability'] >= y_bounds[0]) & (df_3d['Availability'] <= y_bounds[1]) & \
       (df_3d['Dollars Above Affordability'] >= z_bounds[0]) & (df_3d['Dollars Above Affordability'] <= z_bounds[1])

# Filter the DataFrame to Keep Only Points INSIDE the Region
# This is the key step. We create a new DataFrame from the mask.
df_in_region = df_3d[mask].copy() # .copy() is used to avoid a SettingWithCopyWarning

# Display the change in size
print(f"Points in original DataFrame: {len(df_3d)}")
print(f"Points after filtering for region: {len(df_in_region)}")

# Visualize Only the Points from the Selected Region
# Notice the first argument is now our new, filtered DataFrame.
fig = px.scatter_3d(
    df_in_region, # <-- We are using the filtered data here
    x='Quality',
    y='Availability',
    z='Dollars Above Affordability',
    color='cluster',
    text='State_Name',
    hover_name='State_Name',
    title="3D K-Means: Showing Only Points in Selected Region",
    labels={'cluster': 'Cluster ID'}
)

fig.update_traces(textposition='top center')
fig.show()
# Out:
# Points in original DataFrame: 50
# Points after filtering for region: 3
